# %%
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

# %%
data = pd.read_csv("breast-cancer-wisconsin.data")

# %%
data.replace('?', -99999, inplace=True)
data.drop(['id'], axis=1)
# Out:
#      clumpthickness  uniformcellsize  uniformcellshape  margadhesion  \
# 0                 5                1                 1             1
# 1                 5                4                 4             5
# 2                 3                1                 1             1
# 3                 6                8                 8             1
# 4                 4                1                 1             3
# ..              ...              ...               ...           ...
# 694               3                1                 1             1
# 695               2                1                 1             1
# 696               5               10                10             3
# 697               4                8                 6             4
# 698               4                8                 8             5
#
#      epithelial barenuclei  blandchromatin  normalnucleoli  mitoses  benormal
# ...

# %%
y = data.benormal
x = data.drop(['benormal'], axis=1)

# %%
imp = SimpleImputer(missing_values= np.NAN, strategy= 'mean', fill_value=None, verbose=0, copy=True)

x = imp.fit_transform(x)

# %%
predict = KNeighborsClassifier(n_neighbors=3, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='euclidean', metric_params=None, n_jobs=1)
predict.fit(x,y)
ypredict = predict.predict(x)

# %%
success = accuracy_score(y, ypredict, normalize=True, sample_weight=None)
print("Success ",success*100," in Percent:" )

print(predict.predict([1,2,2,2,3,2,1,2,3,2]))
# Out:
# Success  80.25751072961373  in Percent:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-40428036d263> in <module>
#       2 print("Success ",success*100," in Percent:" )
#       3
# ----> 4 print(predict.predict([1,2,2,2,3,2,1,2,3,2]))
#
# D:\Users\xboys\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py in predict(self, X)
#     193             Class labels for each data sample.
#     194         """
# --> 195         X = check_array(X, accept_sparse='csr')
#     196
#     197         neigh_dist, neigh_ind = self.kneighbors(X)
#
# D:\Users\xboys\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ...

# %%
for z in range(25):
    z = 2*z+1
    print("Rate of consistency with nearest neighbor ",z)
    precict = KNeighborsClassifier(n_neighbors=z, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='euclidean', metric_params=None, n_jobs=1)
    predict.fit(x,y)
    ypredict = predict.predict(x)

    success = accuracy_score(y, ypredict, normalize=True, sample_weight=None)
    print(success)
# Out:
# Rate of consistency with nearest neighbor  1
# 0.8025751072961373
# Rate of consistency with nearest neighbor  3
# 0.8025751072961373
# Rate of consistency with nearest neighbor  5
# 0.8025751072961373
# Rate of consistency with nearest neighbor  7
# 0.8025751072961373
# Rate of consistency with nearest neighbor  9
# 0.8025751072961373
# Rate of consistency with nearest neighbor  11
# 0.8025751072961373
# Rate of consistency with nearest neighbor  13
# 0.8025751072961373
# Rate of consistency with nearest neighbor  15
# 0.8025751072961373
# Rate of consistency with nearest neighbor  17
# 0.8025751072961373
# Rate of consistency with nearest neighbor  19
# 0.8025751072961373
# Rate of consistency with nearest neighbor  21
# 0.8025751072961373
# Rate of consistency with nearest neighbor  23
# 0.8025751072961373
# Rate of consistency with nearest neighbor  25
# 0.8025751072961373
# Rate of consistency with nearest neighbor  27
# 0.8025751072961373
# ...
